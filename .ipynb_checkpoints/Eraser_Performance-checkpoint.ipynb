# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scripts.data_importer import DataImporter

# %%
data_obj = DataImporter(using_sample=True, demographics=True)
data_obj.combine_data()

# %%
plt.hist(data_obj.demographics["height_centimeters"], bins=10)
# Out:
# (array([1., 0., 0., 2., 1., 1., 2., 0., 0., 2.]),
#  array([152.4  , 155.194, 157.988, 160.782, 163.576, 166.37 , 169.164,
#         171.958, 174.752, 177.546, 180.34 ]),
#  <a list of 10 Patch objects>)

# %%
data_obj.group_means()
# Out:
#     par_id    condition  trial  speed  error_rate handedness height gender  \
# 0      111  board_erase      1   10.5         NaN      right   5'10      M
# 1      111  board_erase      2    8.7         NaN      right   5'10      M
# 2      111  board_erase      3   15.2         NaN      right   5'10      M
# 3      112  board_erase      1    8.5         NaN      right    5'7      M
# 4      112  board_erase      2    9.2         NaN      right    5'7      M
# 5      112  board_erase      3   14.2         NaN      right    5'7      M
# 6      113  board_erase      1   16.5         NaN       left    5'4      F
# 7      113  board_erase      2   19.4         NaN       left    5'4      F
# 8      113  board_erase      3   11.8         NaN       left    5'4      F
# 9      211  board_erase      1   10.5         NaN       left    5'5      F
# 10     211  board_erase      2    8.7         NaN       left    5'5      F
# 11     211  board_erase      3   15.2         NaN       left    5'5      F
# 12     212  board_erase      1    8.5         NaN      right    5'7      F
# 13     212  board_erase      2    9.2         NaN      right    5'7      F
# 14     212  board_erase      3   14.2         NaN      right    5'7      F
# 15     213  board_erase      1   16.5         NaN       left    5'4      M
# 16     213  board_erase      2   19.4         NaN       left    5'4      M
# 17     213  board_erase      3   11.8         NaN       left    5'4      M
# 18     311  board_erase      1   10.5         NaN      right    5'0      F
# 19     311  board_erase      2    8.7         NaN      right    5'0      F
# 20     311  board_erase      3   15.2         NaN      right    5'0      F
# 21     312  board_erase      1    8.5         NaN      right    5'6      F
# 22     312  board_erase      2    9.2         NaN      right    5'6      F
# 23     312  board_erase      3   14.2         NaN      right    5'6      F
# 24     313  board_erase      1   16.5         NaN       left   5'11      M
# 25     313  board_erase      2   19.4         NaN       left   5'11      M
# 26     313  board_erase      3   11.8         NaN       left   5'11      M
#
#    skill_level well_being  height_inches  height_centimeters  group
# 0       medium     medium           70.0              177.80      1
# 1       medium     medium           70.0              177.80      1
# 2       medium     medium           70.0              177.80      1
# 3       medium     medium           67.0              170.18      1
# 4       medium     medium           67.0              170.18      1
# 5       medium     medium           67.0              170.18      1
# 6         high       good           64.0              162.56      1
# 7         high       good           64.0              162.56      1
# 8         high       good           64.0              162.56      1
# 9          low     medium           65.0              165.10      2
# 10         low     medium           65.0              165.10      2
# 11         low     medium           65.0              165.10      2
# 12         low     medium           67.0              170.18      2
# 13         low     medium           67.0              170.18      2
# 14         low     medium           67.0              170.18      2
# 15      medium        low           64.0              162.56      2
# 16      medium        low           64.0              162.56      2
# 17      medium        low           64.0              162.56      2
# 18        high       high           60.0              152.40      3
# 19        high       high           60.0              152.40      3
# 20        high       high           60.0              152.40      3
# 21        high        low           66.0              167.64      3
# 22        high        low           66.0              167.64      3
# 23        high        low           66.0              167.64      3
# 24         low        low           71.0              180.34      3
# 25         low        low           71.0              180.34      3
# 26         low        low           71.0              180.34      3
